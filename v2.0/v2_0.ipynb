# %%
from farmObj import Farm

# %%
f = Farm()
f.addFemale(18)
f.run(180)
# Out:
# [buying] cash -17000, $-17000
# At the end of Month 0
# [estate] animal age:18 price 17000
# [estate] money -17000 and estate 17000 makes it 0
# At the end of Month 1
# [feeding] cash -120, $-17120
# At the end of Month 2
# [feeding] cash -120, $-17240
# At the end of Month 3
# [feeding] cash -120, $-17360
# At the end of Month 4
# [feeding] cash -120, $-17480
# At the end of Month 5
# [feeding] cash -120, $-17600
# At the end of Month 6
# [feeding] cash -120, $-17720
# At the end of Month 7
# [feeding] cash -120, $-17840
# At the end of Month 8
# [feeding] cash -120, $-17960
# At the end of Month 9
# [feeding] cash -120, $-18080
# At the end of Month 10
# [feeding] cash -120, $-18200
# Congrats! newborn male Cub and pack size goes to  2
# At the end of Month 11
# [feeding] cash -120, $-18320
# [feeding] cash -350, $-18670
# At the end of Month 12
# [feeding] cash -120, $-18790
# [feeding] cash -350, $-19140
# [estate] animal age:30 price 17000
# [estate] animal age:2 price 12000
# ...
