# %%
from farmObj import Farm

# %%
f = Farm()
f.addFemale(18)
f.run(180)
# Out:
# feeding, cash -120, $-120
# feeding, cash -120, $-240
# feeding, cash -120, $-360
# feeding, cash -120, $-480
# feeding, cash -120, $-600
# feeding, cash -120, $-720
# feeding, cash -120, $-840
# feeding, cash -120, $-960
# feeding, cash -120, $-1080
# feeding, cash -120, $-1200
# Congrats! newborn male Cub and pack size goes to  2
# feeding, cash -350, $-1550
# feeding, cash -120, $-1670
# feeding, cash -350, $-2020
# feeding, cash -120, $-2140
# feeding, cash -350, $-2490
# obj age:30 price 17000
# obj age:3 price 29000
# money -2490 and estate 29000 makes it 26510
# feeding, cash -120, $-2610
# feeding, cash -350, $-2960
# feeding, cash -120, $-3080
# feeding, cash -350, $-3430
# feeding, cash -120, $-3550
# feeding, cash -350, $-3900
# feeding, cash -120, $-4020
# feeding, cash -350, $-4370
# feeding, cash -120, $-4490
# feeding, cash -350, $-4840
# feeding, cash -120, $-4960
# feeding, cash -350, $-5310
# feeding, cash -120, $-5430
# feeding, cash -350, $-5780
# ...
