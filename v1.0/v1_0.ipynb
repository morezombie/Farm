# %%
from main import CattleFarm as Farm

# %%
f=Farm()

# %%
f.calc(15)
# Out:
# sing: [ 0.    1.6  -0.4   1.2   1.6   2.2   3.    4.1   5.6   7.65 10.45 14.27
#  19.5  26.64 36.39]
# prof: [  0.     1.6    1.2    2.4    4.     6.2    9.2   13.3   18.9   26.55
#   37.    51.27  70.77  97.41 133.8 ]

# %%
f.calcFromConfig(10,10,15)
# Out:
# sing: [ 0.  32.  38.8 -6.   4.  10.  24.  21.  23.  28.  40.  50.5 62.  76.
#  96. ]
# prof: [  0.   32.   70.8  64.8  68.8  78.8 102.8 123.8 146.8 174.8 214.8 265.3
#  327.3 403.3 499.3]
